# %%
import numpy as np
from fft_tdse_simulator.simulator import *
from fft_tdse_simulator.animator import *
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %%
x_min = -10
x_max = 10
y_min = -10
y_max = 10
nx = 512
ny = 512

def potential(x, y):
   
    return 3 * y * (y >= -8) + 40 * (y < -8)


def init_wavefunction(x, y, sigma_x = 0.5, sigma_y = 0.5, k_x = 5.0, k_y = 0.0, x0 = -5.0, y0 = 0):
    norm = 1.0/np.sqrt(sigma_x*sigma_y*np.pi)
    return np.exp(-(x-x0)**2/(2*sigma_x) - (y-y0)**2/(2*sigma_y) + 1j*k_x*x + 1j*k_y*y) * norm

# %%
sim = Simulator(verbose=True)
sim.set_dimension(2)
sim.set_initial_condition(lambda x, y: init_wavefunction(x, y))
sim.set_mass(10.0)
sim.set_potential(lambda x, y: potential(x,y))
sim.set_grid([x_min, y_min], [x_max, y_max], [nx, ny])
sim.set_time_parameters(0.0, 20.0, 8000)
sim.prepare()
# Out:
# ic| message: 'Dimension set to 2'
# ic| message: 'Initial condition set.'
# ic| self.initial_psi_fun: <function <lambda> at 0x108ae1ab0>
# ic| 'Time grid:'
# ic| self.t0: 0.0, self.t1: 20.0, self.n_steps: 8000

# %%
plt.figure()
plt.imshow(sim.ham.V.T, origin='lower')
plt.title('Potential')
plt.colorbar()
plt.show()

# %%
anim1 = Animator2d(sim, folder='./frames1/')
anim1.vis_type = 'complex'
anim1.show_axis = True

anim2 = Animator2d(sim, folder='./frames2/')
anim2.vis_type = 'magnitude'
anim2.show_axis = True

anim1.set_interval(10)
anim1.set_framesize(1024, 1024)
anim2.set_interval(10)
anim2.set_framesize(1024, 1024)

# initialize figure, and add potential visualization
anim1.init_figure()
anim1.add_potential_visualization_2d(transparent_range=[-50,39])
anim2.init_figure()
anim2.add_potential_visualization_2d(transparent_range=[-50,39])


anim_callback1 = anim1.get_callback()
anim_callback2 = anim2.get_callback()

def callback(sim):
    anim_callback1(sim)
    anim_callback2(sim)
    
sim.simulate(callback=callback)
anim1.make_movie("gravity.mp4")
anim1.clean_frames()
anim2.make_movie("gravity_magnitude.mp4")
anim2.clean_frames()
# Out:
# ic| self.format: './frames1/frame%05d.png'
# ic| self.format: './frames2/frame%05d.png'
# ic| 'Running simulation...'
#   0%|          | 0/8000 [00:00<?, ?it/s]
# ic| len(self.frame_list): 800
# ffmpeg version N-111795-g95433eb3aa-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
#   configuration: --cc=/usr/bin/clang --prefix=/opt/ffmpeg --extra-version=tessus --enable-avisynth --enable-fontconfig --enable-gpl --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libfreetype --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libmysofa --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenh264 --enable-libopenjpeg --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvmaf --enable-libvo-amrwbenc --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-version3 --pkg-config-flags=--static --disable-ffplay
#   libavutil      58. 17.100 / 58. 17.100
#   libavcodec     60. 23.100 / 60. 23.100
#   libavformat    60. 10.100 / 60. 10.100
#   libavdevice    60.  2.101 / 60.  2.101
#   libavfilter     9. 11.100 /  9. 11.100
#   libswscale      7.  3.100 /  7.  3.100
#   libswresample   4. 11.100 /  4. 11.100
#   libpostproc    57.  2.100 / 57.  2.100
# Input #0, image2, from './frames1/frame%05d.png':
#   Duration: 00:00:32.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1024x1024 [SAR 4031:4031 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fe29d70f200] using SAR=1/1
# [libx264 @ 0x7fe29d70f200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2
# [libx264 @ 0x7fe29d70f200] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x7fe29d70f200] 264 - core 164 r3107 a8b68eb - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'gravity.mp4':
#   Metadata:
#     encoder         : Lavf60.10.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc60.23.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x7fe29d7063c0] video:846kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.199341%
# frame=  800 fps=218 q=-1.0 Lsize=     856kB time=00:00:33.20 bitrate= 211.1kbits/s speed=9.04x
# [libx264 @ 0x7fe29d70f200] frame I:4     Avg QP:17.88  size: 24646
# [libx264 @ 0x7fe29d70f200] frame P:211   Avg QP:22.66  size:  3077
# [libx264 @ 0x7fe29d70f200] frame B:585   Avg QP:27.82  size:   201
# [libx264 @ 0x7fe29d70f200] consecutive B-frames:  2.2%  0.5%  0.8% 96.5%
# [libx264 @ 0x7fe29d70f200] mb I  I16..4: 20.3% 76.8%  2.9%
# [libx264 @ 0x7fe29d70f200] mb P  I16..4:  0.4%  0.4%  0.0%  P16..4:  8.1%  2.2%  1.2%  0.0%  0.0%    skip:87.6%
# [libx264 @ 0x7fe29d70f200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  2.9%  0.0%  0.0%  direct: 0.0%  skip:97.0%  L0:47.0% L1:47.8% BI: 5.2%
# [libx264 @ 0x7fe29d70f200] 8x8 transform intra:67.9% inter:69.5%
# [libx264 @ 0x7fe29d70f200] coded y,uvDC,uvAC intra: 15.0% 22.0% 15.6% inter: 1.3% 1.9% 0.3%
# [libx264 @ 0x7fe29d70f200] i16 v,h,dc,p: 32% 40% 18% 10%
# [libx264 @ 0x7fe29d70f200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 57%  6% 34%  0%  0%  0%  0%  0%  1%
# [libx264 @ 0x7fe29d70f200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 43% 13%  2%  1%  1%  1%  1%  3%
# [libx264 @ 0x7fe29d70f200] i8c dc,h,v,p: 78% 16%  4%  2%
# [libx264 @ 0x7fe29d70f200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fe29d70f200] ref P L0: 57.6%  8.6% 27.5%  6.2%
# [libx264 @ 0x7fe29d70f200] ref B L0: 86.0% 13.1%  0.9%
# [libx264 @ 0x7fe29d70f200] ref B L1: 98.4%  1.6%
# [libx264 @ 0x7fe29d70f200] kb/s:207.65
# ic| len(self.frame_list): 800
# ffmpeg version N-111795-g95433eb3aa-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
#   configuration: --cc=/usr/bin/clang --prefix=/opt/ffmpeg --extra-version=tessus --enable-avisynth --enable-fontconfig --enable-gpl --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libfreetype --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libmysofa --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenh264 --enable-libopenjpeg --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvmaf --enable-libvo-amrwbenc --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-version3 --pkg-config-flags=--static --disable-ffplay
#   libavutil      58. 17.100 / 58. 17.100
#   libavcodec     60. 23.100 / 60. 23.100
#   libavformat    60. 10.100 / 60. 10.100
#   libavdevice    60.  2.101 / 60.  2.101
#   libavfilter     9. 11.100 /  9. 11.100
#   libswscale      7.  3.100 /  7.  3.100
#   libswresample   4. 11.100 /  4. 11.100
#   libpostproc    57.  2.100 / 57.  2.100
# Input #0, image2, from './frames2/frame%05d.png':
#   Duration: 00:00:32.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1024x1024 [SAR 4031:4031 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7faee6b0a340] using SAR=1/1
# [libx264 @ 0x7faee6b0a340] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2
# [libx264 @ 0x7faee6b0a340] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x7faee6b0a340] 264 - core 164 r3107 a8b68eb - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'gravity_magnitude.mp4':
#   Metadata:
#     encoder         : Lavf60.10.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc60.23.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x7faee6b04a00] video:325kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.148079%
# frame=  800 fps=229 q=-1.0 Lsize=     335kB time=00:00:33.20 bitrate=  82.6kbits/s speed=9.51x
# [libx264 @ 0x7faee6b0a340] frame I:4     Avg QP:17.84  size:  6482
# [libx264 @ 0x7faee6b0a340] frame P:202   Avg QP:22.50  size:   796
# [libx264 @ 0x7faee6b0a340] frame B:594   Avg QP:30.72  size:   244
# [libx264 @ 0x7faee6b0a340] consecutive B-frames:  1.0%  0.0%  0.0% 99.0%
# [libx264 @ 0x7faee6b0a340] mb I  I16..4: 22.5% 75.3%  2.3%
# [libx264 @ 0x7faee6b0a340] mb P  I16..4:  1.8%  1.1%  0.1%  P16..4:  5.2%  0.4%  0.1%  0.0%  0.0%    skip:91.4%
# [libx264 @ 0x7faee6b0a340] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  3.9%  0.1%  0.0%  direct: 0.0%  skip:95.9%  L0:51.4% L1:47.4% BI: 1.2%
# [libx264 @ 0x7faee6b0a340] 8x8 transform intra:51.7% inter:83.3%
# [libx264 @ 0x7faee6b0a340] coded y,uvDC,uvAC intra: 8.5% 0.7% 0.5% inter: 0.1% 0.0% 0.0%
# [libx264 @ 0x7faee6b0a340] i16 v,h,dc,p: 23% 37%  1% 40%
# [libx264 @ 0x7faee6b0a340] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 15% 33%  1%  1%  1%  1%  1%  0%
# [libx264 @ 0x7faee6b0a340] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 62% 13%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x7faee6b0a340] i8c dc,h,v,p: 96%  3%  1%  0%
# [libx264 @ 0x7faee6b0a340] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7faee6b0a340] ref P L0: 72.1%  1.1% 22.8%  4.1%
# [libx264 @ 0x7faee6b0a340] ref B L0: 86.8% 11.4%  1.8%
# [libx264 @ 0x7faee6b0a340] ref B L1: 95.6%  4.4%
# [libx264 @ 0x7faee6b0a340] kb/s:79.62
